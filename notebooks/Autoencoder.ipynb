# %%
from keras.datasets import mnist
import numpy as np
from keras.layers import Input, Dense, Flatten, Reshape, Activation, concatenate
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization,Conv2DTranspose
from keras.models import Model
import keras.backend as K
from keras.layers import Lambda
import glob, os
import keras
from keras.preprocessing.image import ImageDataGenerator
import cv2
from tqdm import tqdm
import pandas as pd

import gc

base_dir = 'Selfie-dataset/images' 
batch_size = 128
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('Selfie-dataset/selfie_dataset.csv')
df = df[(df.partial_faces == 0) & (df.baby == 0) & (df.child == 0)]
images = []
for i in tqdm(range(int(df['image_name'].shape[0]/2))):
    file = df['image_name'].iloc[i]
    img = cv2.imread(base_dir+'/'+file+'.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (32,32)) / 255
    images.append(img)
images = np.array(images)
#gc.collect()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 18040/18040 [00:20<00:00, 899.96it/s]

# %%
def create_deep_conv_ae():
    input_img = Input(shape=(32, 32, 3))
    x = Conv2D(32, (3, 3), padding='same')(input_img)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), padding='same')(x)
    x = Conv2D(32, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    encoded = MaxPooling2D((2, 2), padding='same')(x)

    x = Conv2D(32, (3, 3), padding='same')(encoded)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(32, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(3, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    decoded = Activation('sigmoid')(x)
    
    model = Model(inputs=[input_img], outputs=[decoded])
    
    model.summary()
    
    return encoded, decoded, model

# %%
def create_denoising_model(autoencoder):
    def add_noise(x):
        noise_factor = 0.1
        x = x + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x.get_shape()) 
        x = K.clip(x, 0., 1.)
        #noise_factor = 0.5
        #x = x + K.random_normal(x.get_shape(), 0.5, noise_factor)
        #x = K.clip(x, 0., 1.)
        return x

    input_img  = Input(batch_shape=(batch_size, 32, 32, 3))
    noised_img = Lambda(add_noise)(input_img)

    noiser = Model(input_img, noised_img, name="noiser")
    denoiser_model = Model(input_img, autoencoder(noiser(input_img)), name="denoiser")
    return noiser, denoiser_model

# %%
c_encoder, c_decoder, c_autoencoder = create_deep_conv_ae()

noiser, denoiser_model = create_denoising_model(c_autoencoder)
denoiser_model.compile(optimizer='adam', loss='binary_crossentropy')

#c_autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
denoiser_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_14 (InputLayer)        (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_30 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 16, 16, 32)        9248
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# activation_31 (Activation)   (None, 16, 16, 32)        0
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 8, 8, 32)          9248
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 8, 8, 32)          128
# _________________________________________________________________
# activation_32 (Activation)   (None, 8, 8, 32)          0
# _________________________________________________________________
# up_sampling2d_12 (UpSampling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 16, 16, 32)        9248
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# activation_33 (Activation)   (None, 16, 16, 32)        0
# _________________________________________________________________
# up_sampling2d_13 (UpSampling (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 32, 32, 3)         867
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 32, 32, 3)         12
# _________________________________________________________________
# activation_34 (Activation)   (None, 32, 32, 3)         0
# =================================================================
# Total params: 30,031
# Trainable params: 29,769
# Non-trainable params: 262
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_15 (InputLayer)        (128, 32, 32, 3)          0
# _________________________________________________________________
# noiser (Model)               (128, 32, 32, 3)          0
# _________________________________________________________________
# model_7 (Model)              multiple                  30031
# =================================================================
# Total params: 30,031
# Trainable params: 29,769
# Non-trainable params: 262
# _________________________________________________________________

# %%
denoiser_model.fit(images[:-(images.shape[0]%batch_size)],images[:-(images.shape[0]%batch_size)],
                epochs=20, batch_size=batch_size)
# Out:
# Epoch 1/20
# 17920/17920 [==============================] - ETA: 4:09 - loss: 0.799 - ETA: 1:02 - loss: 0.700 - ETA: 36s - loss: 0.656 - ETA: 25s - loss: 0.63 - ETA: 19s - loss: 0.61 - ETA: 16s - loss: 0.60 - ETA: 13s - loss: 0.59 - ETA: 11s - loss: 0.59 - ETA: 10s - loss: 0.58 - ETA: 9s - loss: 0.5843 - ETA: 8s - loss: 0.581 - ETA: 7s - loss: 0.577 - ETA: 6s - loss: 0.575 - ETA: 6s - loss: 0.573 - ETA: 5s - loss: 0.571 - ETA: 5s - loss: 0.569 - ETA: 4s - loss: 0.568 - ETA: 4s - loss: 0.566 - ETA: 4s - loss: 0.565 - ETA: 3s - loss: 0.563 - ETA: 3s - loss: 0.562 - ETA: 3s -
- ETA: 2s - loss: 0.493 - ETA: 2s - loss: 0.493 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.493 - ETA: 0s - loss: 0.493 - ETA: 0s - loss: 0.493 - ETA: 0s - loss: 0.493 - ETA: 0s - loss: 0.493 - ETA: 0s - loss: 0.493 - ETA: 0s - loss: 0.493 - ETA: 0s - loss: 0.493 - ETA: 0s - loss: 0.493 - ETA: 0s - loss: 0.493 - ETA: 0s - loss: 0.493 - ETA: 0s - loss: 0.493 - ETA: 0s - loss: 0.493 - ETA: 0s - loss: 0.493 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - 2s 138us/step - loss: 0.4926
# Epoch 13/20
# 17920/17920 [==============================] - ETA: 2s - loss: 0.510 - ETA: 2s - loss: 0.493 - ETA: 2s - loss: 0.494 - ETA: 2s - loss: 0.492 - ETA: 2s - loss: 0.492 - ETA: 2s - loss: 0.491 - ETA: 2s - loss: 0.491 - ETA: 2s - loss: 0.492 - ETA: 2s - loss: 0.493 - ETA: 2s - loss: 0.492 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 0s - loss: 0.491 - ETA: 0s - loss: 0.491 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.491 - ETA: 0s - loss: 0.491 - ETA: 0s - loss: 0.491 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.491 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.491 - ETA: 0s - loss: 0.491 - 2s 139us/step - loss: 0.4920
# Epoch 14/20
# 17920/17920 [==============================] - ETA: 2s - loss: 0.491 - ETA: 2s - loss: 0.493 - ETA: 2s - loss: 0.494 - ETA: 2s - loss: 0.495 - ETA: 2s - loss: 0.494 - ETA: 2s - loss: 0.495 - ETA: 2s - loss: 0.494 - ETA: 2s - loss: 0.493 - ETA: 2s - loss: 0.493 - ETA: 1s - loss: 0.494 - ETA: 1s - loss: 0.494 - ETA: 1s - loss: 0.494 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.493 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.492 - ETA: 0s - loss: 0.491 - ETA: 0s - loss: 0.491 - ETA: 0s - loss: 0.491 - ETA: 0s - loss: 0.491 - ETA: 0s - loss: 0.491 - ETA: 0s - loss: 0.491 - ETA: 0s - loss: 0.491 - ETA: 0s - loss: 0.491 - ETA: 0s - loss: 0.491 - ETA: 0s - loss: 0.491 - 2s 139us/step - loss: 0.4915
# Epoch 15/20
# 17920/17920 [==============================] - ETA: 2s - loss: 0.493 - ETA: 2s - loss: 0.492 - ETA: 2s - loss: 0.489 - ETA: 2s - loss: 0.491 - ETA: 2s - loss: 0.492 - ETA: 2s - loss: 0.492 - ETA: 2s - loss: 0.492 - ETA: 2s - loss: 0.492 - ETA: 2s - loss: 0.492 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.491 - ETA: 0s - loss: 0.490 - 2s 137us/step - loss: 0.4910
# Epoch 16/20
# 17920/17920 [==============================] - ETA: 2s - loss: 0.491 - ETA: 2s - loss: 0.492 - ETA: 2s - loss: 0.495 - ETA: 2s - loss: 0.493 - ETA: 2s - loss: 0.493 - ETA: 2s - loss: 0.491 - ETA: 2s - loss: 0.491 - ETA: 2s - loss: 0.491 - ETA: 2s - loss: 0.492 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.492 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.491 - ETA: 0s - loss: 0.491 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - 2s 138us/step - loss: 0.4907
# Epoch 17/20
# 17920/17920 [==============================] - ETA: 2s - loss: 0.504 - ETA: 2s - loss: 0.493 - ETA: 2s - loss: 0.490 - ETA: 2s - loss: 0.489 - ETA: 2s - loss: 0.488 - ETA: 2s - loss: 0.489 - ETA: 2s - loss: 0.488 - ETA: 2s - loss: 0.490 - ETA: 2s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - 2s 139us/step - loss: 0.4902
# Epoch 18/20
# 17920/17920 [==============================] - ETA: 2s - loss: 0.494 - ETA: 2s - loss: 0.491 - ETA: 2s - loss: 0.490 - ETA: 2s - loss: 0.489 - ETA: 2s - loss: 0.489 - ETA: 2s - loss: 0.490 - ETA: 2s - loss: 0.489 - ETA: 2s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - ETA: 0s - loss: 0.490 - 2s 135us/step - loss: 0.4900
# Epoch 19/20
# 17920/17920 [==============================] - ETA: 2s - loss: 0.477 - ETA: 2s - loss: 0.488 - ETA: 2s - loss: 0.489 - ETA: 2s - loss: 0.489 - ETA: 2s - loss: 0.490 - ETA: 2s - loss: 0.490 - ETA: 2s - loss: 0.489 - ETA: 2s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - 2s 137us/step - loss: 0.4897
# Epoch 20/20
# 17920/17920 [==============================] - ETA: 2s - loss: 0.488 - ETA: 2s - loss: 0.488 - ETA: 2s - loss: 0.486 - ETA: 2s - loss: 0.488 - ETA: 2s - loss: 0.488 - ETA: 2s - loss: 0.491 - ETA: 2s - loss: 0.491 - ETA: 2s - loss: 0.490 - ETA: 1s - loss: 0.491 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.490 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 1s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - ETA: 0s - loss: 0.489 - 2s 135us/step - loss: 0.4894

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

def plot_digits(*args):
    args = [x.squeeze() for x in args]
    n = min([x.shape[0] for x in args])
    
    plt.figure(figsize=(2*n, 2*len(args)))
    for j in range(n):
        for i in range(len(args)):
            ax = plt.subplot(len(args), n, i*n + j + 1)
            plt.imshow(args[i][j])
            plt.gray()
            ax.get_xaxis().set_visible(False)
            ax.get_yaxis().set_visible(False)

    plt.show()

# %%
n = 10

imgs = images[:n]
encoded_imgs = c_autoencoder.predict(imgs, batch_size=n)
encoded_imgs[0]
# Out:
# array([[[0.3164868 , 0.3056831 , 0.2860652 ],
#         [0.27005476, 0.29184172, 0.27525598],
#         [0.32570034, 0.33837858, 0.29411587],
#         ...,
#         [0.45183414, 0.47904858, 0.4049577 ],
#         [0.4496739 , 0.48182103, 0.4121241 ],
#         [0.47016063, 0.47331482, 0.41487917]],
#
#        [[0.30630702, 0.3152803 , 0.29045373],
#         [0.28718337, 0.32456213, 0.27427772],
#         [0.3150052 , 0.35412443, 0.29243428],
#         ...,
#         [0.4346618 , 0.5110032 , 0.39941028],
#         [0.46489173, 0.5455781 , 0.4224967 ],
#         [0.45866624, 0.49804702, 0.41362265]],
#
#        [[0.4127309 , 0.41004625, 0.34733245],
#         [0.39999595, 0.4166755 , 0.34338787],
#         [0.3918999 , 0.40627033, 0.34477305],
#         ...,
#         [0.51701427, 0.57979566, 0.4628559 ],
#         [0.5320431 , 0.61035687, 0.476455  ],
#         [0.5021255 , 0.5500557 , 0.44794756]],
#
#        ...,
#
#        [[0.5634572 , 0.572269  , 0.48090154],
#         [0.67386025, 0.6984821 , 0.5680824 ],
#         [0.6245351 , 0.6450884 , 0.54521304],
#         ...,
#         [0.09465116, 0.03069047, 0.10013335],
#         [0.10232994, 0.03682029, 0.10699501],
#         [0.09396061, 0.0461208 , 0.10390398]],
#
#        [[0.2823743 , 0.28156778, 0.23507695],
#         [0.28747123, 0.30167803, 0.25083715],
#         [0.27684715, 0.27887   , 0.25517786],
#         ...,
#         [0.08171405, 0.03046714, 0.10032613],
#         [0.09430367, 0.03652744, 0.10231495],
#         [0.09986372, 0.0487083 , 0.10453442]],
#
#        [[0.21572147, 0.1817523 , 0.1883334 ],
#         [0.16976912, 0.15781692, 0.16119412],
#         [0.15223   , 0.13677035, 0.15622205],
#         ...,
#         [0.09281196, 0.04135096, 0.10086834],
#         [0.10086169, 0.04770546, 0.10872604],
#         [0.13215236, 0.07517146, 0.14265497]]], dtype=float32)

# %%
decoded_imgs = c_autoencoder.predict(encoded_imgs, batch_size=n)

plot_digits(imgs, decoded_imgs)

# %%
plt.imshow(images[0])
